# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
    
def plot_res(filename):
    res = pd.read_csv(filename)


    # Create a figure with two subplots side by side

    # Plot data on the first subplot
    ax = res[["train_acc", "val_acc"]].plot()
    ax.set_title('Accuracy')
    ax.set_ylabel('Accuracy Value')
    ax.set_xlabel('Epoch')

    # Plot data on the second subplot
    #res[["train_acc", "val_acc"]].plot(ax=axes[1])
    #axes[1].set_title('Accuracy')
    #axes[1].set_ylabel('Accuracy Value')
    #axes[1].set_xlabel('Epoch')

    # Adjust the layout and show the plot
    plt.tight_layout()
    plt.show()

# %%
plot_res("results13.csv")

# %%
plot_res("results1.csv")

# %% [markdown]
# hidden = 10
#
# class CNN(nn.Module):
#         def __init__(self,
#                  input_shape: int,
#                  hidden_units: int,
#                  output_shape: int):
#             super().__init__()
#
#             self.conv_block_1 = nn.Sequential(
#             nn.Conv2d(in_channels= input_shape,
#                     out_channels= hidden_units,
#                     kernel_size=3,
#                     stride=1,
#                     padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size = 2))
#
#             self.conv_block_2 = nn.Sequential(
#             nn.Conv2d(in_channels= hidden_units,
#                     out_channels= hidden_units,
#                     kernel_size=3,
#                     stride=1,
#                     padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size=2),
#             nn.Dropout2d(p=0.4)
#             )
#
#             self.classifier = nn.Sequential(
#             nn.Flatten(),
#             nn.Linear(in_features= hidden_units * 64 * 64 ,
#                     out_features = output_shape))
#
#         def forward(self, x):
#             x = self.conv_block_1(x)
#             #print(f"After 1. block: {x.shape}")
#             x = self.conv_block_2(x)
#             #print(f"After 2. block: {x.shape}")
#             x= self.classifier(x)
#             #print(f"After classifier: {x.shape}")
#             return x

# %%
res = pd.read_csv("results2.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Round 3
#
#     hidden = 10
#     ## Defining the model
#     class CNN(nn.Module):
#         def __init__(self,
#                  input_shape: int,
#                  hidden_units: int,
#                  output_shape: int):
#             super().__init__()
#
#             self.conv_block_1 = nn.Sequential(
#             nn.Conv2d(in_channels= input_shape,
#                     out_channels= hidden_units,
#                     kernel_size=3,
#                     stride=1,
#                     padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size = 4))
#
#             self.conv_block_2 = nn.Sequential(
#             nn.Conv2d(in_channels= hidden_units,
#                     out_channels= hidden_units,
#                     kernel_size=3,
#                     stride=1,
#                     padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size=2),
#             nn.Dropout2d(p=0.4)
#             )
#
#             self.classifier = nn.Sequential(
#             nn.Flatten(),
#             nn.Linear(in_features= hidden_units * 64 * 64 ,
#                     out_features = output_shape))
#
#         def forward(self, x):
#             x = self.conv_block_1(x)
#             #print(f"After 1. block: {x.shape}")
#             #x = self.conv_block_2(x)
#             #print(f"After 2. block: {x.shape}")
#             x= self.classifier(x)
#             #print(f"After classifier: {x.shape}")
#             return x

# %%
res = pd.read_csv("results3.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Round 4
#
#     hidden = 3
#     ## Defining the model
#     class CNN(nn.Module):
#         def __init__(self,
#                  input_shape: int,
#                  hidden_units: int,
#                  output_shape: int):
#             super().__init__()
#
#             self.conv_block_1 = nn.Sequential(
#             nn.Conv2d(in_channels= input_shape,
#                     out_channels= hidden_units,
#                     kernel_size=3,
#                     stride=1,
#                     padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size = 2))
#
#             self.conv_block_2 = nn.Sequential(
#             nn.Conv2d(in_channels= hidden_units,
#                     out_channels= hidden_units,
#                     kernel_size=3,
#                     stride=1,
#                     padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size=2),
#             nn.Dropout2d(p=0.7)
#             )
#
#             self.classifier = nn.Sequential(
#             nn.Flatten(),
#             nn.Linear(in_features= hidden_units * 64 * 64 ,
#                     out_features = output_shape))
#
#         def forward(self, x):
#             x = self.conv_block_1(x)
#             #print(f"After 1. block: {x.shape}")
#             x = self.conv_block_2(x)
#             #print(f"After 2. block: {x.shape}")
#             x= self.classifier(x)
#             #print(f"After classifier: {x.shape}")
#             return x

# %%
res = pd.read_csv("results4.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Round 5
#
#     hidden = 3
#     ## Defining the model
#     class CNN(nn.Module):
#         def __init__(self,
#                  input_shape: int,
#                  hidden_units: int,
#                  output_shape: int):
#             super().__init__()
#
#             self.conv_block_1 = nn.Sequential(
#             nn.Conv2d(in_channels= input_shape,
#                     out_channels= hidden_units,
#                     kernel_size=3,
#                     stride=1,
#                     padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size = 2))
#
#             self.conv_block_2 = nn.Sequential(
#             nn.Conv2d(in_channels= hidden_units,
#                     out_channels= hidden_units,
#                     kernel_size=3,
#                     stride=1,
#                     padding=1),
#             nn.ReLU(),
#             nn.MaxPool2d(kernel_size=2),
#             nn.Dropout2d(p=0.7)
#             )
#
#             self.classifier = nn.Sequential(
#             nn.Flatten(),
#             nn.Linear(in_features= hidden_units * 64 * 64 ,
#                     out_features = output_shape))
#
#         def forward(self, x):
#             x = self.conv_block_1(x)
#             #print(f"After 1. block: {x.shape}")
#             x = self.conv_block_2(x)
#             #print(f"After 2. block: {x.shape}")
#             x= self.classifier(x)
#             #print(f"After classifier: {x.shape}")
#             return x

# %%
res = pd.read_csv("results5.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Looks like it is not overfitting anymore, but also not learning any generalized, so maybe more overfitting prevention and more complexity
#
# so dropout from 0.7 to 0.9
# and adding another convolutional block

# %% [markdown]
# # 6
# 3 conv blocks
#     hidden= 3, kernel= 2
#     dropouts = 0
#
# 1 Linear layer
#
# lr = 0.001
# wd = 1e-4

# %%
res = pd.read_csv("results6.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# nothing is happening so canceling the try and increasing the learningrate from 0.001 to 0.005

# %% [markdown]
# # 7
# 3 conv blocks
#     hidden= 3, kernel= 2
#     dropouts = 0, 0.9, 0.9
#
# 1 Linear layer
#
# lr = 0.005
# wd = 1e-4

# %%
res = pd.read_csv("results7.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# still not learning anything
#
# removing the 3rd block -> less complexity
# but adding another fc classifier layer with dropout 0.5
# learningrate also down again from 0.005 -> 0.002

# %% [markdown]
# # 8
#
# 3 conv blocks
#     hidden= 3, kernel= 2
#     dropouts = 0, 0.9, 0.9
#
# 2 Linear layer
#     hidden = 500
#     dropout = 0.5
#
#
# lr = 0.002 wd = 1e-4

# %%
res = pd.read_csv("results8.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# still nothing
# maybe removing the weigh_decay and increasing lr from 0.002 -> 0.003

# %% [markdown]
# # 9
#
# 2 conv blocks
#     hidden= 3
#     kernel= 2, 2
#     dropouts = 0, 0.9
#
# 2 Linear layer
#     hidden = 500
#     dropout = 0.5
#
#
# lr = 0.003 wd = 0

# %%
res = pd.read_csv("results9.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# hm still not learning anythin ://
#
# so increasing the kernel_size for the maxpool from 2 -> 4
# and removing the second fc classifier layer again
#
# (lr again down to 0.002)

# %% [markdown]
# # 10
#
# 2 conv blocks
#     hidden= 3,
#     kernel= 4, 4
#     dropouts = 0.8, 0.8
#
# 1 Linear layer
#
#
#
# lr = 0.002 wd = 1e-4

# %%
res = pd.read_csv("results10.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# at least it is overfitting again :D <br>
# but maybe we should try to take some dropout away <br>
# dropouts now from 0.8 -> 0.05 for both conv nets<br>
# and wd down to 1e-8 (so 0)

# %% [markdown]
# # 11
#
# 2 conv blocks hidden= 3, kernel= 4, 4 dropouts = 0.05, 0.05
#
# 1 Linear layer
#
# lr = 0.002 wd = 1e-8

# %%
res = pd.read_csv("results11.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Ok, we really have to change something now:
# hidden_units to 10 again
# data augmentation:
# - RandomHorizontalFlip(p=0.5)
# - RandomRotation(10)
# - RandomResizedCrop(256, scale=(0.8, 1.0))
# - ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1)
#
# First kernelsizes 7 and 5<br>
# no wd anymore

# %% [markdown]
# # 12
#
# 2 conv with 2 blocks
#
#
#
# does nothing
# vanishing gradients
#
# -> higher learningrate

# %%
res = pd.read_csv("results12.csv")
# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# well not really an advancement<br>
# lr from 0.002 to 0.05

# %% [markdown]
# # 13
#
# lr 0.05
#
# still nothing

# %%
res = pd.read_csv("results13.csv")


# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# well no, that did not work, i guess everything was not complex and good enough, so now we are doing a res net <br>
# - lr decrease to 0.001 <br>
# - 3 res blocks with each 3 conv layers
# - 1 conv block in the beginning with kernel 7 and 5

# %% [markdown]
# # 14
# ein res net mit
# - 1 conv
# - 3 Res Blöcke
# - 1 average pooling
# - 2 fc

# %%
import matplotlib.pyplot as plt

res = pd.read_csv("results14.csv")


# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# it worked, now it trains, looks really good <br>
# lets give it more complexity and higher learning rate 0.001->0.003

# %% [markdown]
# # 15
# ein res net mit
# - 1 conv
# - 5 Res Blöcke
# - 1 average pooling
# - 2 fc

# %%
res = pd.read_csv("results15.csv")


# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# more generalization <br>
# adding another BatchNorm2d and adding dropout in every resnet

# %% [markdown]
# # 17

# %%
res = pd.read_csv("results17.csv")


# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
res[["train_loss", "val_loss"]].plot(ax=axes[0])
axes[0].set_title('Loss')
axes[0].set_ylabel('Loss Value')
axes[0].set_xlabel('Epoch')

# Plot data on the second subplot
res[["train_acc", "val_acc"]].plot(ax=axes[1])
axes[1].set_title('Accuracy')
axes[1].set_ylabel('Accuracy Value')
axes[1].set_xlabel('Epoch')

# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# well it is not overfitting anymore, but it trains slower? at least it is worse than try 14, even though it has 2 more layers and is not overfitting <br>
# maybe with more time and a higher learning rate it would be better than 14... <br>
# i think just to understand, I will take out all batchnormalization for a try

# %% [markdown]
# # FROM HERE ON CHANGES:
# #### BATCH SIZE = 32
# #### AVG POOLING 4,4
# #### NUMBER OF HIDDEN UNITS 16!!
#
# Based on model 14, improved. No reflective padding bc of the error, idk why.

# %%
    
def plot_res(filename):
    res = pd.read_csv(filename)


    # Create a figure with two subplots side by side
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

    # Plot data on the first subplot
    res[["train_loss", "val_loss"]].plot(ax=axes[0])
    axes[0].set_title('Loss')
    axes[0].set_ylabel('Loss Value')
    axes[0].set_xlabel('Epoch')

    # Plot data on the second subplot
    res[["train_acc", "val_acc"]].plot(ax=axes[1])
    axes[1].set_title('Accuracy')
    axes[1].set_ylabel('Accuracy Value')
    axes[1].set_xlabel('Epoch')

    # Adjust the layout and show the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 20

# %% [markdown]
# dropouts in basic blocks
#
#         x = self.conv2(self.dropout(self.conv1(x))) #conv -> dropout -> conv
#
#         x = self.relu(x)
#
#         x = self.bn2(x)
#
# average pooling bigger size (4,4)
#
# LR 0.001
# BATCHSIZE 32

# %%
plot_res('results20.csv')

# %% [markdown]
# # 22

# %% [markdown]
# test20 with LR = 0.01

# %%
plot_res('results22.csv')

# %% [markdown]
# # 21 - Best So Far
#
# no dropout in basic block, once between resblocks.
# LR = 0.001
#
# avg pooling with 4,4

# %%
plot_res('results21.csv')

# %% [markdown]
# # 23
#
# 21 + more augmentations / autoaugment + LR = 0.01

# %%
plot_res('results23.csv')

# %% [markdown]
# # 24
#
# 21 + AdamW and scheduler

# %%
df_24 = pd.read_csv('results24.csv')
print(df_24['val_acc'].max())
df_24[-10:]
# Out:
# 67.96875
#     epoch  train_loss  train_acc  val_loss    val_acc
# 50     50    1.166926  63.478793  1.051975  66.903409
# 51     51    1.143852  64.085440  1.059645  66.832386
# 52     52    1.128924  64.686990  1.051656  67.329545
# 53     53    1.121315  64.697186  1.067932  66.264205
# 54     54    1.111401  64.763458  1.028863  67.542614
# 55     55    1.102406  65.115212  1.033926  67.968750
# 56     56    1.098335  65.635196  1.033771  67.400568
# 57     57    1.091403  65.563825  1.032693  67.613636
# 58     58    1.098172  65.405791  1.030488  67.968750
# 59     59    1.096546  65.512847  1.035842  67.755682

# %%
plot_res('results24.csv')

# %% [markdown]
# Same code as 24 - but NUM_EPOCHS = 240. So LR Scheduler acts differently.

# %%
plot_res('results24_longer.csv')

# %% [markdown]
# # 25
#
# hidden layers expanding, avg pool 2x2

# %%
plot_res('results25.csv')

# %%
df_25 = pd.read_csv('results25.csv')
print(df_25['val_acc'].max())
df_25[-10:]
# Out:
# 67.30587121212122
#     epoch  train_loss  train_acc  val_loss    val_acc
# 50     50    1.137845  64.248573  1.160972  62.973485
# 51     51    1.115569  64.814437  1.124133  65.767045
# 52     52    1.091832  65.477162  1.138817  65.033144
# 53     53    1.102472  65.232463  1.126925  65.317235
# 54     54    1.086582  65.400693  1.154516  65.459280
# 55     55    1.074298  65.941069  1.108687  66.098485
# 56     56    1.066461  66.338703  1.131862  65.317235
# 57     57    1.070536  66.002243  1.098282  67.305871
# 58     58    1.068158  66.313214  1.102466  66.524621
# 59     59    1.064875  66.328507  1.099524  67.092803

# %%
# Comparison test 24 and test 25

# Create a figure with two subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 6))

# Plot data on the first subplot
df_24[["val_acc"]].plot(ax=axes[0], color='green')
df_25[["val_acc"]].plot(ax=axes[0], color='blue',)

axes[0].set_title('Accuracy')
axes[0].set_ylabel('Accuracy Value')
axes[0].set_xlabel('Epoch')

# Plot data on the first subplot
df_24[["val_loss"]].plot(ax=axes[1], color='green')
df_25[["val_loss"]].plot(ax=axes[1], color='blue',)

axes[1].set_title('Loss')
axes[1].set_ylabel('Loss Value')
axes[1].set_xlabel('Epoch')


# Adjust the layout and show the plot
plt.tight_layout()
plt.show()

# %%
plot_res('results26.csv')
df_26 = pd.read_csv('results26.csv')
print(df_26['val_acc'].max())
# Out:
# 75.16571969696969

# %%
plot_res('results27.csv')
df_27 = pd.read_csv('results27.csv')
print(df_27['val_acc'].max())
# Out:
# 74.17140151515152

# %% [markdown]
# # BEST MODEL
#
# LR = 0.0001

# %%
plot_res('results28.csv')
df_28 = pd.read_csv('results28.csv')
print(df_28['val_acc'].max(), df_28['train_acc'][df_28['val_acc'].argmax()] )
# Out:
# 75.97064393939394 76.08075040783034

# %%
import pandas as pd
df_28 = pd.read_csv('results28.csv')
print(df_28["val_acc"][-50:].mean())
print(df_28["train_acc"][-50:].mean())
print(df_28["val_acc"][:].max())
print(df_28["train_acc"][:].max())
# Out:
# 72.87452651515152
# 75.70626019575856
# 75.97064393939394
# 76.4783849918434

# %% [markdown]
# ### load model. perform on validation.
# ### do confusion matrix
# ### testing

# %%
# Model
import torch
import torch.nn as nn


class BasicBlock(nn.Module):
    # Scale factor of the number of output channels
    expansion = 1

    def __init__(self, in_channels, out_channels,
                 stride=1, is_first_block=False):
        """
        Args:
            in_channels: number of input channels
            out_channels: number of output channels
            stride: stride using in (a) the first 3x3 convolution and
                    (b) 1x1 convolution used for downsampling for skip connection
            is_first_block: whether it is the first residual block of the layer
        """
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channels,
                               out_channels=out_channels,
                               kernel_size=3,
                               stride=stride,
                               padding=1)
        self.conv2 = nn.Conv2d(in_channels=out_channels,
                               out_channels=out_channels,
                               kernel_size=3,
                               stride=1,
                               padding=1)
        self.relu = nn.ReLU()
        self.bn2 = nn.BatchNorm2d(out_channels)


    def forward(self, x):
        """
        Args:
            x: input
        Returns:
            Residual block ouput
        """
        identity = x.clone()
        x = self.conv2((self.conv1(x))) #conv -> dropout -> conv
        x = self.relu(x)
        x = self.bn2(x) # BN lecture: bn after relu is okay, if before use parameters

        x += identity

        return x



class RNN(nn.Module):
    def __init__(self,
                 input_shape: int,
                 hidden_units: int,
                 output_shape: int):
        super().__init__()

        self.conv_block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units*2,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )

        self.res_block_1 = nn.Sequential(
        			        BasicBlock(in_channels=hidden_units*2,
                                       out_channels=hidden_units*2, stride=1, is_first_block=False),
                            BasicBlock(in_channels=hidden_units*2,
                                       out_channels=hidden_units*2, stride=1, is_first_block=False),
                            BasicBlock(in_channels=hidden_units*2,
                                       out_channels=hidden_units*2, stride=1, is_first_block=False),
                                       )

        self.res_block_2 = nn.Sequential(
            BasicBlock(in_channels=hidden_units * 2,
                       out_channels=hidden_units * 2, stride=1, is_first_block=False),
            BasicBlock(in_channels=hidden_units * 2,
                       out_channels=hidden_units * 2, stride=1, is_first_block=False),
            BasicBlock(in_channels=hidden_units * 2,
                       out_channels=hidden_units * 2, stride=1, is_first_block=False),
        )

        self.dropout = nn.Dropout2d(p=0.05)

        self.res_block_3 = nn.Sequential(
            BasicBlock(in_channels=hidden_units * 2,
                       out_channels=hidden_units * 2, stride=1, is_first_block=False),
            BasicBlock(in_channels=hidden_units * 2,
                       out_channels=hidden_units * 2, stride=1, is_first_block=False),
            BasicBlock(in_channels=hidden_units * 2,
                       out_channels=hidden_units * 2, stride=1, is_first_block=False),
        )

        self.avgpool = nn.AdaptiveAvgPool2d((4, 4))

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=512,
                      out_features=64),
            nn.Dropout2d(p=0.5),
            nn.Linear(in_features=64,
                      out_features=output_shape))

    def forward(self, x):
        x = self.conv_block_1(x)
        #print(f"After 1. block: {x.shape}")
        x = self.res_block_1(x)
        #print(f"After res block: {x.shape}")
        x = self.res_block_2(x)
        #print(f"After res block: {x.shape}")
        x = self.res_block_3(x)
        #print(f"After res block: {x.shape}")
        x = self.avgpool(x)
        #print(f"After avgpool: {x.shape}")
        x = self.classifier(x)
        #print(f"After classifier: {x.shape}")
        return x

# %%
model = RNN(3,16,29)
checkpoint = torch.load('../models/model_cpt.pth',map_location=torch.device('cpu'))
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
try:
  from torchinfo import summary
except:
  # !pip install torchinfo
  from torchinfo import summary
# Out:
# ...
#   Obtaining dependency information for torchinfo from https://files.pythonhosted.org/packages/72/25/973bd6128381951b23cdcd8a9870c6dcfc5606cb864df8eabd82e529f9c1/torchinfo-1.8.0-py3-none-any.whl.metadata
# ...

# %%
input_size=(8, 3, 256, 256)
summary(model,  col_names=["input_size","output_size", "num_params", "kernel_size", "mult_adds"], input_size= input_size)
# Out:
# /Users/nurayagaoglu/anaconda3/lib/python3.11/site-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# ...
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds
# ...
# RNN                                      [8, 3, 256, 256]          [8, 29]                   --                        --                        --
# ├─Sequential: 1-1                        [8, 3, 256, 256]          [8, 32, 128, 128]         --                        --                        --
# ...
